# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the Latitudes and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | jiaozuo
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | richards bay
# Processing Record 15 of Set 1 | mandalgovi
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | grand gaube
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | alofi
# Processing Record 21 of Set 1 | palmer
# Processing Record 22 of Set 1 | dubbo
# Processing Record 23 of Set 1 | port lincoln
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | aripuana
# Processing Record 27 of Set 1 | bilma
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | pangobilian
# Processing Record 30 of Set 1 | loandjili
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | belsand
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | baghdad
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | chumphon
# Processing Record 38 of Set 1 | mufumbwe
# Processing Record 39 of Set 1 | hobyo
# Processing Record 40 of Set 1 | hofn
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | yauco
# Processing Record 43 of Set 1 | eureka
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | airai
# Processing Record 46 of Set 1 | tabou
# Processing Record 47 of Set 1 | georgiyevka
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | nowy dwor gdanski
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | belaya gora
# Processing Record 3 of Set 2 | bubaque
# Processing Record 4 of Set 2 | dedza
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | te anau
# Processing Record 7 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 2 | izumo
# Processing Record 9 of Set 2 | leh
# Processing Record 10 of Set 2 | arraial do cabo
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | puri
# Processing Record 15 of Set 2 | podgornoye
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | shasta lake
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | riviere-au-renard
# Processing Record 20 of Set 2 | etchojoa
# Processing Record 21 of Set 2 | saint pete beach
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | vuktyl
# Processing Record 24 of Set 2 | san quintin
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | dharchula
# Processing Record 27 of Set 2 | tokyo
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 2 | bredasdorp
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | hami
# Processing Record 35 of Set 2 | awbari
# Processing Record 36 of Set 2 | salalah
# Processing Record 37 of Set 2 | hithadhoo
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | tateyama
# Processing Record 40 of Set 2 | sangar
# Processing Record 41 of Set 2 | khaga
# Processing Record 42 of Set 2 | souillac
# Processing Record 43 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 2 | samarai
# Processing Record 45 of Set 2 | nemuro
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | fomboni
# Processing Record 48 of Set 2 | guerrero negro
# Processing Record 49 of Set 2 | lebu
# Processing Record 50 of Set 2 | hammerfest
# Processing Record 1 of Set 3 | jishou
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | riohacha
# Processing Record 4 of Set 3 | torbay
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | yerbogachen
# Processing Record 7 of Set 3 | russell
# Processing Record 8 of Set 3 | waingapu
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | tuatapere
# Processing Record 12 of Set 3 | hobart
# Processing Record 13 of Set 3 | mount pleasant
# Processing Record 14 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 3 | proddatur
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | mar del plata
# Processing Record 18 of Set 3 | victoria
# Processing Record 19 of Set 3 | havoysund
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | pisco
# Processing Record 22 of Set 3 | abu samrah
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | hay river
# Processing Record 25 of Set 3 | kavieng
# Processing Record 26 of Set 3 | srednekolymsk
# Processing Record 27 of Set 3 | sur
# Processing Record 28 of Set 3 | deputatskiy
# Processing Record 29 of Set 3 | kiruna
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | chuy
# Processing Record 34 of Set 3 | havre
# Processing Record 35 of Set 3 | esfahan
# Processing Record 36 of Set 3 | codrington
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | san patricio
# Processing Record 39 of Set 3 | cacu
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | aljezur
# Processing Record 42 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 3 | laguna
# Processing Record 44 of Set 3 | port blair
# Processing Record 45 of Set 3 | boende
# Processing Record 46 of Set 3 | aklavik
# Processing Record 47 of Set 3 | provideniya
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | chokurdakh
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | seka
# Processing Record 4 of Set 4 | najran
# Processing Record 5 of Set 4 | havre-saint-pierre
# Processing Record 6 of Set 4 | hajnowka
# Processing Record 7 of Set 4 | salzwedel
# Processing Record 8 of Set 4 | luanda
# Processing Record 9 of Set 4 | nelson bay
# Processing Record 10 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 4 | mahon
# Processing Record 12 of Set 4 | caravelas
# Processing Record 13 of Set 4 | san cristobal
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | pacific grove
# Processing Record 16 of Set 4 | antalaha
# Processing Record 17 of Set 4 | quatre cocos
# Processing Record 18 of Set 4 | dunedin
# Processing Record 19 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 4 | mahebourg
# Processing Record 22 of Set 4 | yar-sale
# Processing Record 23 of Set 4 | gazanjyk
# Processing Record 24 of Set 4 | ischia
# Processing Record 25 of Set 4 | melilla
# Processing Record 26 of Set 4 | sal rei
# Processing Record 27 of Set 4 | pervoye maya
# Processing Record 28 of Set 4 | gondanglegi
# Processing Record 29 of Set 4 | oranjestad
# Processing Record 30 of Set 4 | polunochnoye
# Processing Record 31 of Set 4 | solnechnyy
# Processing Record 32 of Set 4 | dikson
# Processing Record 33 of Set 4 | sambava
# Processing Record 34 of Set 4 | kahului
# Processing Record 35 of Set 4 | houma
# Processing Record 36 of Set 4 | floro
# Processing Record 37 of Set 4 | saint-philippe
# Processing Record 38 of Set 4 | sisophon
# Processing Record 39 of Set 4 | iqaluit
# Processing Record 40 of Set 4 | khatanga
# Processing Record 41 of Set 4 | tual
# Processing Record 42 of Set 4 | maisach
# Processing Record 43 of Set 4 | krasnyy yar
# Processing Record 44 of Set 4 | ambulu
# Processing Record 45 of Set 4 | padang
# Processing Record 46 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 47 of Set 4 | naze
# Processing Record 48 of Set 4 | baturaja
# Processing Record 49 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 4 | manicore
# Processing Record 1 of Set 5 | pallasovka
# Processing Record 2 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 5 | tongliao
# Processing Record 4 of Set 5 | olafsvik
# Processing Record 5 of Set 5 | cidreira
# Processing Record 6 of Set 5 | lagoa
# Processing Record 7 of Set 5 | avarua
# Processing Record 8 of Set 5 | aurangabad
# Processing Record 9 of Set 5 | hokitika
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 13 of Set 5 | nanchong
# Processing Record 14 of Set 5 | kavaratti
# Processing Record 15 of Set 5 | bria
# Processing Record 16 of Set 5 | bay roberts
# Processing Record 17 of Set 5 | rio cuarto
# Processing Record 18 of Set 5 | cayenne
# Processing Record 19 of Set 5 | waiblingen
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | comodoro rivadavia
# Processing Record 22 of Set 5 | birin
# Processing Record 23 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 5 | hasaki
# Processing Record 25 of Set 5 | pangnirtung
# Processing Record 26 of Set 5 | muroto
# Processing Record 27 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | zalantun
# Processing Record 31 of Set 5 | esil
# Processing Record 32 of Set 5 | juba
# Processing Record 33 of Set 5 | port hedland
# Processing Record 34 of Set 5 | meulaboh
# Processing Record 35 of Set 5 | salinopolis
# Processing Record 36 of Set 5 | kieta
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | yanaul
# Processing Record 39 of Set 5 | fukue
# Processing Record 40 of Set 5 | shenandoah
# Processing Record 41 of Set 5 | quimper
# Processing Record 42 of Set 5 | nanakuli
# Processing Record 43 of Set 5 | port-cartier
# Processing Record 44 of Set 5 | aquiraz
# Processing Record 45 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 5 | namatanai
# Processing Record 48 of Set 5 | angoche
# Processing Record 49 of Set 5 | ambon
# Processing Record 50 of Set 5 | erzin
# Processing Record 1 of Set 6 | wairoa
# Processing Record 2 of Set 6 | nokaneng
# Processing Record 3 of Set 6 | zhuhai
# Processing Record 4 of Set 6 | sorland
# Processing Record 5 of Set 6 | ponta delgada
# Processing Record 6 of Set 6 | bambous virieux
# Processing Record 7 of Set 6 | freeport
# Processing Record 8 of Set 6 | jinxi
# Processing Record 9 of Set 6 | berdigestyakh
# Processing Record 10 of Set 6 | noumea
# Processing Record 11 of Set 6 | maracas
# Processing Record 12 of Set 6 | half moon bay
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | troitskoye
# Processing Record 15 of Set 6 | mehamn
# Processing Record 16 of Set 6 | nouadhibou
# Processing Record 17 of Set 6 | shebalino
# Processing Record 18 of Set 6 | mizdah
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 6 | nara
# Processing Record 22 of Set 6 | copiapo
# Processing Record 23 of Set 6 | castro
# Processing Record 24 of Set 6 | bahia blanca
# Processing Record 25 of Set 6 | sheboygan
# Processing Record 26 of Set 6 | den helder
# Processing Record 27 of Set 6 | vardo
# Processing Record 28 of Set 6 | muros
# Processing Record 29 of Set 6 | vestmannaeyjar
# Processing Record 30 of Set 6 | ust-kuyga
# Processing Record 31 of Set 6 | bossangoa
# Processing Record 32 of Set 6 | progreso
# Processing Record 33 of Set 6 | pangody
# Processing Record 34 of Set 6 | karasjok
# Processing Record 35 of Set 6 | pakhtakoron
# Processing Record 36 of Set 6 | boca do acre
# Processing Record 37 of Set 6 | safaga
# Processing Record 38 of Set 6 | gwadar
# Processing Record 39 of Set 6 | college
# Processing Record 40 of Set 6 | camacha
# Processing Record 41 of Set 6 | valparaiso
# Processing Record 42 of Set 6 | nikolskoye
# Processing Record 43 of Set 6 | katsuura
# Processing Record 44 of Set 6 | indiana
# Processing Record 45 of Set 6 | miraflores
# Processing Record 46 of Set 6 | poltavka
# Processing Record 47 of Set 6 | hamilton
# Processing Record 48 of Set 6 | neiafu
# Processing Record 49 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 6 | leua
# Processing Record 1 of Set 7 | borogontsy
# Processing Record 2 of Set 7 | puerto escondido
# Processing Record 3 of Set 7 | mount gambier
# Processing Record 4 of Set 7 | ambilobe
# Processing Record 5 of Set 7 | yaan
# Processing Record 6 of Set 7 | thompson
# Processing Record 7 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 8 of Set 7 | bardiyah
# Processing Record 9 of Set 7 | vizinga
# Processing Record 10 of Set 7 | martil
# Processing Record 11 of Set 7 | nuuk
# Processing Record 12 of Set 7 | jiuquan
# Processing Record 13 of Set 7 | ballina
# Processing Record 14 of Set 7 | oktyabrskoye
# Processing Record 15 of Set 7 | iquitos
# Processing Record 16 of Set 7 | fairbanks
# Processing Record 17 of Set 7 | finschhafen
# Processing Record 18 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 7 | jiaocheng
# Processing Record 20 of Set 7 | faya
# Processing Record 21 of Set 7 | oka
# Processing Record 22 of Set 7 | huadian
# Processing Record 23 of Set 7 | tanout
# Processing Record 24 of Set 7 | berbera
# Processing Record 25 of Set 7 | deh rawud
# City not found. Skipping...
# Processing Record 26 of Set 7 | los llanos de aridane
# Processing Record 27 of Set 7 | margate
# Processing Record 28 of Set 7 | viedma
# Processing Record 29 of Set 7 | burica
# City not found. Skipping...
# Processing Record 30 of Set 7 | aykhal
# Processing Record 31 of Set 7 | namibe
# Processing Record 32 of Set 7 | biloela
# Processing Record 33 of Set 7 | amontada
# Processing Record 34 of Set 7 | ola
# Processing Record 35 of Set 7 | novo aripuana
# Processing Record 36 of Set 7 | pilar
# Processing Record 37 of Set 7 | yambio
# Processing Record 38 of Set 7 | kudahuvadhoo
# Processing Record 39 of Set 7 | fairview
# Processing Record 40 of Set 7 | talaigua
# City not found. Skipping...
# Processing Record 41 of Set 7 | meadow lake
# Processing Record 42 of Set 7 | broome
# Processing Record 43 of Set 7 | bondoukou
# Processing Record 44 of Set 7 | nichinan
# Processing Record 45 of Set 7 | hovd
# Processing Record 46 of Set 7 | svetlogorsk
# Processing Record 47 of Set 7 | ambunti
# Processing Record 48 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 7 | ambovombe
# Processing Record 50 of Set 7 | nhulunbuy
# Processing Record 1 of Set 8 | vanavara
# Processing Record 2 of Set 8 | waddan
# Processing Record 3 of Set 8 | bongouanou
# Processing Record 4 of Set 8 | asau
# Processing Record 5 of Set 8 | huanuni
# Processing Record 6 of Set 8 | nueva italia
# Processing Record 7 of Set 8 | klaksvik
# Processing Record 8 of Set 8 | chislaz
# Processing Record 9 of Set 8 | xining
# Processing Record 10 of Set 8 | ulaanbaatar
# Processing Record 11 of Set 8 | walvis bay
# Processing Record 12 of Set 8 | aksarka
# Processing Record 13 of Set 8 | general roca
# Processing Record 14 of Set 8 | acajutla
# Processing Record 15 of Set 8 | sanandaj
# Processing Record 16 of Set 8 | ostrovnoy
# Processing Record 17 of Set 8 | sao pedro do sul
# Processing Record 18 of Set 8 | tanete
# Processing Record 19 of Set 8 | isla
# Processing Record 20 of Set 8 | damietta
# Processing Record 21 of Set 8 | mackay
# Processing Record 22 of Set 8 | longmont
# Processing Record 23 of Set 8 | topeka
# Processing Record 24 of Set 8 | hualmay
# Processing Record 25 of Set 8 | coahuayana
# Processing Record 26 of Set 8 | tuim
# Processing Record 27 of Set 8 | tura
# Processing Record 28 of Set 8 | talnakh
# Processing Record 29 of Set 8 | tarifa
# Processing Record 30 of Set 8 | malatya
# Processing Record 31 of Set 8 | birjand
# Processing Record 32 of Set 8 | preston
# Processing Record 33 of Set 8 | binga
# Processing Record 34 of Set 8 | kiama
# Processing Record 35 of Set 8 | paamiut
# Processing Record 36 of Set 8 | gigmoto
# Processing Record 37 of Set 8 | liling
# Processing Record 38 of Set 8 | kayerkan
# Processing Record 39 of Set 8 | martapura
# Processing Record 40 of Set 8 | mondlo
# Processing Record 41 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 8 | oranjemund
# Processing Record 43 of Set 8 | duz
# City not found. Skipping...
# Processing Record 44 of Set 8 | arlit
# Processing Record 45 of Set 8 | scalea
# Processing Record 46 of Set 8 | jiayuguan
# Processing Record 47 of Set 8 | akureyri
# Processing Record 48 of Set 8 | balkanabat
# Processing Record 49 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 8 | saraipali
# Processing Record 1 of Set 9 | saint-augustin
# Processing Record 2 of Set 9 | bulaevo
# Processing Record 3 of Set 9 | iracoubo
# Processing Record 4 of Set 9 | clinton
# Processing Record 5 of Set 9 | marawi
# Processing Record 6 of Set 9 | zarichne
# Processing Record 7 of Set 9 | saint-claude
# Processing Record 8 of Set 9 | isangel
# Processing Record 9 of Set 9 | hargeysa
# Processing Record 10 of Set 9 | dyersburg
# Processing Record 11 of Set 9 | igrim
# Processing Record 12 of Set 9 | bend
# Processing Record 13 of Set 9 | kenai
# Processing Record 14 of Set 9 | bethel
# Processing Record 15 of Set 9 | general pico
# Processing Record 16 of Set 9 | mitsamiouli
# Processing Record 17 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 18 of Set 9 | kyren
# Processing Record 19 of Set 9 | sadiqabad
# Processing Record 20 of Set 9 | wassenaar
# Processing Record 21 of Set 9 | manaus
# Processing Record 22 of Set 9 | beloha
# Processing Record 23 of Set 9 | san francisco de coray
# Processing Record 24 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 9 | santa maria
# Processing Record 27 of Set 9 | anadyr
# Processing Record 28 of Set 9 | faanui
# Processing Record 29 of Set 9 | portland
# Processing Record 30 of Set 9 | miranda
# Processing Record 31 of Set 9 | chatham
# Processing Record 32 of Set 9 | brigantine
# Processing Record 33 of Set 9 | limbe
# Processing Record 34 of Set 9 | williston
# Processing Record 35 of Set 9 | koslan
# Processing Record 36 of Set 9 | elmadag
# Processing Record 37 of Set 9 | farmington
# Processing Record 38 of Set 9 | rabo de peixe
# Processing Record 39 of Set 9 | sydney
# Processing Record 40 of Set 9 | sibiti
# Processing Record 41 of Set 9 | oda
# Processing Record 42 of Set 9 | astorga
# Processing Record 43 of Set 9 | kutum
# Processing Record 44 of Set 9 | kaya
# Processing Record 45 of Set 9 | tigil
# Processing Record 46 of Set 9 | nome
# Processing Record 47 of Set 9 | yurimaguas
# Processing Record 48 of Set 9 | guanare
# Processing Record 49 of Set 9 | kamenka
# Processing Record 50 of Set 9 | berezovyy
# Processing Record 1 of Set 10 | bantou
# Processing Record 2 of Set 10 | lagunas
# Processing Record 3 of Set 10 | boguchany
# Processing Record 4 of Set 10 | ancud
# Processing Record 5 of Set 10 | zhanakorgan
# Processing Record 6 of Set 10 | karwar
# Processing Record 7 of Set 10 | oksfjord
# Processing Record 8 of Set 10 | lakes entrance
# Processing Record 9 of Set 10 | marrakesh
# Processing Record 10 of Set 10 | douala
# Processing Record 11 of Set 10 | constitucion
# Processing Record 12 of Set 10 | ribeira grande
# Processing Record 13 of Set 10 | yulara
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | johi
# Processing Record 16 of Set 10 | boyolangu
# Processing Record 17 of Set 10 | pitkyaranta
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | sao joao da barra
# Processing Record 20 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 10 | wanning
# Processing Record 22 of Set 10 | shimoda
# Processing Record 23 of Set 10 | araouane
# Processing Record 24 of Set 10 | pasighat
# Processing Record 25 of Set 10 | port shepstone
# Processing Record 26 of Set 10 | kegayli
# City not found. Skipping...
# Processing Record 27 of Set 10 | turukhansk
# Processing Record 28 of Set 10 | careiro da varzea
# Processing Record 29 of Set 10 | kolyvan
# Processing Record 30 of Set 10 | mackenzie
# Processing Record 31 of Set 10 | gat
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | zharkent
# Processing Record 34 of Set 10 | bantry
# Processing Record 35 of Set 10 | gambela
# Processing Record 36 of Set 10 | kanigoro
# Processing Record 37 of Set 10 | ulladulla
# Processing Record 38 of Set 10 | uusikaupunki
# Processing Record 39 of Set 10 | muzhi
# Processing Record 40 of Set 10 | rosarito
# Processing Record 41 of Set 10 | muret
# Processing Record 42 of Set 10 | pedasi
# Processing Record 43 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 44 of Set 10 | kardailovo
# Processing Record 45 of Set 10 | kurilsk
# Processing Record 46 of Set 10 | koungou
# Processing Record 47 of Set 10 | quesnel
# Processing Record 48 of Set 10 | almonte
# Processing Record 49 of Set 10 | teruel
# Processing Record 50 of Set 10 | alyangula
# Processing Record 1 of Set 11 | puerto del rosario
# Processing Record 2 of Set 11 | poronaysk
# Processing Record 3 of Set 11 | tocopilla
# Processing Record 4 of Set 11 | betsiamites
# Processing Record 5 of Set 11 | dnipryany
# Processing Record 6 of Set 11 | fountain hills
# Processing Record 7 of Set 11 | laukaa
# Processing Record 8 of Set 11 | diamantino
# Processing Record 9 of Set 11 | cap malheureux
# Processing Record 10 of Set 11 | mapiripan
# Processing Record 11 of Set 11 | sept-iles
# Processing Record 12 of Set 11 | papetoai
# Processing Record 13 of Set 11 | juneau
# Processing Record 14 of Set 11 | chino valley
# Processing Record 15 of Set 11 | mopipi
# Processing Record 16 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 11 | senno
# Processing Record 18 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 11 | puerto cortes
# City not found. Skipping...
# Processing Record 20 of Set 11 | verkhnyaya inta
# Processing Record 21 of Set 11 | kinsale
# Processing Record 22 of Set 11 | north bend
# Processing Record 23 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 24 of Set 11 | marsa matruh
# Processing Record 25 of Set 11 | barinas
# Processing Record 26 of Set 11 | la libertad
# Processing Record 27 of Set 11 | anchorage
# Processing Record 28 of Set 11 | camocim
# Processing Record 29 of Set 11 | ukiah
# Processing Record 30 of Set 11 | awjilah
# Processing Record 31 of Set 11 | moa
# Processing Record 32 of Set 11 | shumskiy
# Processing Record 33 of Set 11 | rioblanco
# Processing Record 34 of Set 11 | mount isa
# Processing Record 35 of Set 11 | vega de alatorre
# Processing Record 36 of Set 11 | alpena
# Processing Record 37 of Set 11 | beringovskiy
# Processing Record 38 of Set 11 | talcahuano
# Processing Record 39 of Set 11 | santa rita
# Processing Record 40 of Set 11 | flinders
# Processing Record 41 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 11 | nyurba
# Processing Record 43 of Set 11 | geneva
# Processing Record 44 of Set 11 | curillo
# Processing Record 45 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 46 of Set 11 | verkhoyansk
# Processing Record 47 of Set 11 | dongsheng
# Processing Record 48 of Set 11 | salamanca
# Processing Record 49 of Set 11 | danielskuil
# Processing Record 50 of Set 11 | tzintzuntzan
# Processing Record 1 of Set 12 | garowe
# Processing Record 2 of Set 12 | lompoc
# Processing Record 3 of Set 12 | kitimat
# Processing Record 4 of Set 12 | kisangani
# Processing Record 5 of Set 12 | alice springs
# Processing Record 6 of Set 12 | kenora
# Processing Record 7 of Set 12 | taksimo
# Processing Record 8 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 12 | juarez
# Processing Record 10 of Set 12 | saint-francois
# Processing Record 11 of Set 12 | keetmanshoop
# Processing Record 12 of Set 12 | batagay-alyta
# Processing Record 13 of Set 12 | huarmey
# Processing Record 14 of Set 12 | albanel
# Processing Record 15 of Set 12 | la asuncion
# Processing Record 16 of Set 12 | rawson
# Processing Record 17 of Set 12 | san policarpo
# Processing Record 18 of Set 12 | bolu
# Processing Record 19 of Set 12 | seoul
# Processing Record 20 of Set 12 | biak
# Processing Record 21 of Set 12 | iowa city
# Processing Record 22 of Set 12 | karpinsk
# Processing Record 23 of Set 12 | hirara
# Processing Record 24 of Set 12 | takaka
# Processing Record 25 of Set 12 | hauterive
# Processing Record 26 of Set 12 | minuri
# Processing Record 27 of Set 12 | surin
# Processing Record 28 of Set 12 | bluefields
# Processing Record 29 of Set 12 | zhangye
# Processing Record 30 of Set 12 | vladyslavivka
# Processing Record 31 of Set 12 | miandrivazo
# Processing Record 32 of Set 12 | luganville
# Processing Record 33 of Set 12 | nang rong
# Processing Record 34 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 12 | ilam
# Processing Record 36 of Set 12 | kuressaare
# Processing Record 37 of Set 12 | kalmunai
# Processing Record 38 of Set 12 | aketi
# Processing Record 39 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 40 of Set 12 | cabedelo
# Processing Record 41 of Set 12 | ouadda
# Processing Record 42 of Set 12 | bismil
# Processing Record 43 of Set 12 | berlevag
# Processing Record 44 of Set 12 | svatove
# Processing Record 45 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 46 of Set 12 | ixtapa
# Processing Record 47 of Set 12 | kota tinggi
# Processing Record 48 of Set 12 | taoudenni
# Processing Record 49 of Set 12 | hanyang
# Processing Record 50 of Set 12 | barwaha
# City not found. Skipping...
# Processing Record 1 of Set 13 | acapulco
# Processing Record 2 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 13 | turayf
# Processing Record 4 of Set 13 | yatou
# Processing Record 5 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 13 | morondava
# Processing Record 7 of Set 13 | aasiaat
# Processing Record 8 of Set 13 | port-gentil
# Processing Record 9 of Set 13 | yairipok
# Processing Record 10 of Set 13 | ilhabela
# Processing Record 11 of Set 13 | kawalu
# Processing Record 12 of Set 13 | umm kaddadah
# Processing Record 13 of Set 13 | vao
# Processing Record 14 of Set 13 | ovalle
# Processing Record 15 of Set 13 | alta floresta
# Processing Record 16 of Set 13 | sitka
# Processing Record 17 of Set 13 | koscierzyna
# Processing Record 18 of Set 13 | komsomolskiy
# Processing Record 19 of Set 13 | vero beach
# Processing Record 20 of Set 13 | rundu
# Processing Record 21 of Set 13 | caucaia
# Processing Record 22 of Set 13 | porto novo
# Processing Record 23 of Set 13 | trairi
# Processing Record 24 of Set 13 | ihosy
# Processing Record 25 of Set 13 | lugoba
# Processing Record 26 of Set 13 | makat
# Processing Record 27 of Set 13 | planeta rica
# Processing Record 28 of Set 13 | zeerust
# Processing Record 29 of Set 13 | faxinal
# Processing Record 30 of Set 13 | roebourne
# Processing Record 31 of Set 13 | saldanha
# Processing Record 32 of Set 13 | kangaba
# Processing Record 33 of Set 13 | pitangueiras
# Processing Record 34 of Set 13 | honningsvag
# Processing Record 35 of Set 13 | darhan
# Processing Record 36 of Set 13 | baijiantan
# Processing Record 37 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 13 | elko
# Processing Record 39 of Set 13 | mandan
# Processing Record 40 of Set 13 | marsaxlokk
# Processing Record 41 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 13 | krizevci
# Processing Record 43 of Set 13 | goderich
# Processing Record 44 of Set 13 | ust-maya
# Processing Record 45 of Set 13 | kantunilkin
# Processing Record 46 of Set 13 | praia da vitoria
# Processing Record 47 of Set 13 | dukat
# Processing Record 48 of Set 13 | tete
# Processing Record 49 of Set 13 | silver city
# Processing Record 50 of Set 13 | kailua
# Processing Record 1 of Set 14 | mahibadhoo
# Processing Record 2 of Set 14 | kajaani
# Processing Record 3 of Set 14 | harper
# Processing Record 4 of Set 14 | coari
# Processing Record 5 of Set 14 | dawei
# Processing Record 6 of Set 14 | sobolevo
# Processing Record 7 of Set 14 | uhlove
# Processing Record 8 of Set 14 | lusambo
# Processing Record 9 of Set 14 | marand
# Processing Record 10 of Set 14 | labuhan
# Processing Record 11 of Set 14 | shelburne
# Processing Record 12 of Set 14 | do gonbadan
# Processing Record 13 of Set 14 | saint anthony
# Processing Record 14 of Set 14 | lorengau
# Processing Record 15 of Set 14 | karaton
# Processing Record 16 of Set 14 | bundaberg
# Processing Record 17 of Set 14 | nalut
# Processing Record 18 of Set 14 | santiago del estero
# Processing Record 19 of Set 14 | ishigaki
# Processing Record 20 of Set 14 | toba
# Processing Record 21 of Set 14 | eslov
# Processing Record 22 of Set 14 | vieste
# Processing Record 23 of Set 14 | ozernovskiy
# Processing Record 24 of Set 14 | kewanee
# Processing Record 25 of Set 14 | kemijarvi
# Processing Record 26 of Set 14 | trinidad
# Processing Record 27 of Set 14 | segou
# Processing Record 28 of Set 14 | ahuimanu
# Processing Record 29 of Set 14 | kamaishi
# Processing Record 30 of Set 14 | koindu
# Processing Record 31 of Set 14 | karratha
# Processing Record 32 of Set 14 | sorong
# Processing Record 33 of Set 14 | patiya
# Processing Record 34 of Set 14 | baiyin
# Processing Record 35 of Set 14 | fershampenuaz
# Processing Record 36 of Set 14 | mecca
# Processing Record 37 of Set 14 | bilibino
# Processing Record 38 of Set 14 | hatillo
# Processing Record 39 of Set 14 | bitung
# Processing Record 40 of Set 14 | hervey bay
# Processing Record 41 of Set 14 | atar
# Processing Record 42 of Set 14 | baraki barak
# Processing Record 43 of Set 14 | thabazimbi
# Processing Record 44 of Set 14 | husavik
# Processing Record 45 of Set 14 | baruun-urt
# Processing Record 46 of Set 14 | dolores
# Processing Record 47 of Set 14 | gotsu
# Processing Record 48 of Set 14 | belyy yar
# Processing Record 49 of Set 14 | nayoro
# Processing Record 50 of Set 14 | somerset
# Processing Record 1 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 2 of Set 15 | ortakoy
# Processing Record 3 of Set 15 | nouakchott
# Processing Record 4 of Set 15 | piacabucu
# Processing Record 5 of Set 15 | rosetta
# Processing Record 6 of Set 15 | mancio lima
# Processing Record 7 of Set 15 | soyo
# Processing Record 8 of Set 15 | murmashi
# Processing Record 9 of Set 15 | chipping sodbury
# Processing Record 10 of Set 15 | astoria
# Processing Record 11 of Set 15 | moose factory
# Processing Record 12 of Set 15 | pundaguitan
# Processing Record 13 of Set 15 | santa luzia
# Processing Record 14 of Set 15 | borskoye
# Processing Record 15 of Set 15 | gamboma
# Processing Record 16 of Set 15 | antofagasta
# Processing Record 17 of Set 15 | inuvik
# Processing Record 18 of Set 15 | chumikan
# Processing Record 19 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 20 of Set 15 | gornopravdinsk
# Processing Record 21 of Set 15 | orange
# Processing Record 22 of Set 15 | zwedru
# Processing Record 23 of Set 15 | funtua
# Processing Record 24 of Set 15 | lanzhou
# Processing Record 25 of Set 15 | pakaur
# Processing Record 26 of Set 15 | hambantota
# Processing Record 27 of Set 15 | akdepe
# Processing Record 28 of Set 15 | nizhnyaya tavda
# Processing Record 29 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 15 | fereydun kenar
# Processing Record 31 of Set 15 | honiara
# Processing Record 32 of Set 15 | alexandria
# Processing Record 33 of Set 15 | bryukhovetskaya
# Processing Record 34 of Set 15 | jega
# Processing Record 35 of Set 15 | sholapur
# Processing Record 36 of Set 15 | skibbereen
# Processing Record 37 of Set 15 | benguela
# Processing Record 38 of Set 15 | kalianget
# Processing Record 39 of Set 15 | nantucket
# Processing Record 40 of Set 15 | rutana
# Processing Record 41 of Set 15 | lingao
# Processing Record 42 of Set 15 | yumen
# Processing Record 43 of Set 15 | bonavista
# Processing Record 44 of Set 15 | suure-jaani
# Processing Record 45 of Set 15 | rawannawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Albany  42.6001  -73.9662     84.61        65          91        2.53
# 1    Cape Town -33.9258   18.4232     59.41        80          75        5.01
# 2    Jamestown  42.0970  -79.2353     82.09        69          20        1.99
# 3      Jiaozuo  35.2397  113.2331     79.23        77          58        3.38
# 4        Kapaa  22.0752 -159.3190     73.38        79          42        3.00
# 5      Fortuna  40.5982 -124.1573     63.86        96          90        6.91
# 6  Yellowknife  62.4560 -114.3525     50.52        57          75        8.05
# 7       Atuona  -9.8000 -139.0333     77.22        81          86       18.41
# 8        Bluff -46.6000  168.3333     35.80        64          64       15.77
# 9      Ushuaia -54.8000  -68.3000     38.55        81          94        4.99
#
#   Country Current Description
# 0      US     overcast clouds
# 1      ZA          light rain
# 2      US          few clouds
# 3      CN          light rain
# 4      US    scattered clouds
# 5      US     overcast clouds
# 6      CA       broken clouds
# 7      PF          light rain
# 8      NZ       broken clouds
# 9      AR     overcast clouds

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Albany      US  42.6001  -73.9662     84.61        65          91
# 1    Cape Town      ZA -33.9258   18.4232     59.41        80          75
# 2    Jamestown      US  42.0970  -79.2353     82.09        69          20
# 3      Jiaozuo      CN  35.2397  113.2331     79.23        77          58
# 4        Kapaa      US  22.0752 -159.3190     73.38        79          42
# 5      Fortuna      US  40.5982 -124.1573     63.86        96          90
# 6  Yellowknife      CA  62.4560 -114.3525     50.52        57          75
# 7       Atuona      PF  -9.8000 -139.0333     77.22        81          86
# 8        Bluff      NZ -46.6000  168.3333     35.80        64          64
# 9      Ushuaia      AR -54.8000  -68.3000     38.55        81          94
#
#    Wind Speed Current Description
# 0        2.53     overcast clouds
# 1        5.01          light rain
# 2        1.99          few clouds
# 3        3.38          light rain
# 4        3.00    scattered clouds
# 5        6.91     overcast clouds
# 6        8.05       broken clouds
# 7       18.41          light rain
# 8       15.77       broken clouds
# 9        4.99     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
